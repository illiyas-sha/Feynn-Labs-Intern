# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !wget https://drive.google.com/file/d/1VLPg79vXiApVDfXSaNZVflARjxLcS7e9/view?usp=sharing
# Out:
# --2021-12-05 07:27:13--  https://drive.google.com/file/d/1VLPg79vXiApVDfXSaNZVflARjxLcS7e9/view?usp=sharing
# Resolving drive.google.com (drive.google.com)... 172.217.204.113, 172.217.204.138, 172.217.204.101, ...
# Connecting to drive.google.com (drive.google.com)|172.217.204.113|:443... connected.
# HTTP request sent, awaiting response... 302 Moved Temporarily
# Location: https://accounts.google.com/ServiceLogin?service=wise&passive=1209600&continue=https://drive.google.com/file/d/1VLPg79vXiApVDfXSaNZVflARjxLcS7e9/view?usp%3Dsharing&followup=https://drive.google.com/file/d/1VLPg79vXiApVDfXSaNZVflARjxLcS7e9/view?usp%3Dsharing [following]
# --2021-12-05 07:27:13--  https://accounts.google.com/ServiceLogin?service=wise&passive=1209600&continue=https://drive.google.com/file/d/1VLPg79vXiApVDfXSaNZVflARjxLcS7e9/view?usp%3Dsharing&followup=https://drive.google.com/file/d/1VLPg79vXiApVDfXSaNZVflARjxLcS7e9/view?usp%3Dsharing
# ...

# %%
# !unzip -u "/content/drive/MyDrive/mcdonalds.zip" -d "/content/drive/MyDrive"
# Out:
# Archive:  /content/drive/MyDrive/mcdonalds.zip

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns 
import plotly as py
import plotly.graph_objs as go
import plotly.figure_factory as ff
import plotly.graph_objects as go
import plotly.express as px
from plotly.subplots import make_subplots

# %%
path_1 = "/content/drive/MyDrive/mcdonalds.csv"
df = pd.read_csv(path_1)
df.head(10)
# Out:
#   yummy convenient spicy  ... Age      VisitFrequency  Gender
# 0    No        Yes    No  ...  61  Every three months  Female
# 1   Yes        Yes    No  ...  51  Every three months  Female
# 2    No        Yes   Yes  ...  62  Every three months  Female
# 3   Yes        Yes    No  ...  69         Once a week  Female
# 4    No        Yes    No  ...  49        Once a month    Male
# 5   Yes        Yes    No  ...  55  Every three months    Male
# 6   Yes        Yes   Yes  ...  56  Every three months  Female
# 7   Yes        Yes    No  ...  23         Once a week  Female
# 8    No         No    No  ...  58         Once a year    Male
# 9   Yes        Yes    No  ...  32  Every three months  Female
#
# [10 rows x 15 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1453 entries, 0 to 1452
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   yummy           1453 non-null   object
#  1   convenient      1453 non-null   object
#  2   spicy           1453 non-null   object
#  3   fattening       1453 non-null   object
#  4   greasy          1453 non-null   object
#  5   fast            1453 non-null   object
#  6   cheap           1453 non-null   object
#  7   tasty           1453 non-null   object
#  8   expensive       1453 non-null   object
#  9   healthy         1453 non-null   object
#  10  disgusting      1453 non-null   object
#  11  Like            1453 non-null   object
#  12  Age             1453 non-null   int64
#  13  VisitFrequency  1453 non-null   object
#  14  Gender          1453 non-null   object
# dtypes: int64(1), object(14)
# memory usage: 170.4+ KB

# %%
df.describe()
# Out:
#                Age
# count  1453.000000
# mean     44.604955
# std      14.221178
# min      18.000000
# 25%      33.000000
# 50%      45.000000
# 75%      57.000000
# max      71.000000

# %%
plt.figure(1 , figsize = (15 , 5))
sns.set(style="darkgrid")
ax = sns.countplot(y="Gender", data=df)

# %%
plt.figure(1 , figsize = (15 , 5))
sns.set(style="darkgrid")
ax = sns.countplot(y="yummy", data=df)

# %%
plt.figure(1 , figsize = (15 , 5))
sns.set(style="darkgrid")
ax = sns.countplot(y="convenient", data=df)

# %%
plt.figure(1 , figsize = (15 , 5))
sns.set(style="darkgrid")
ax = sns.countplot(y="spicy", data=df)

# %%
plt.figure(1 , figsize = (15 , 5))
sns.set(style="darkgrid")
ax = sns.countplot(y="fattening", data=df)

# %%
plt.figure(1 , figsize = (15 , 5))
sns.set(style="darkgrid")
ax = sns.countplot(y="greasy", data=df)

# %%
plt.figure(1 , figsize = (15 , 5))
sns.set(style="darkgrid")
ax = sns.countplot(y="fast", data=df)

# %%
plt.figure(1 , figsize = (15 , 5))
sns.set(style="darkgrid")
ax = sns.countplot(y="cheap", data=df)

# %%
plt.figure(1 , figsize = (15 , 5))
sns.set(style="darkgrid")
ax = sns.countplot(y="tasty", data=df)

# %%
plt.figure(1 , figsize = (15 , 5))
sns.set(style="darkgrid")
ax = sns.countplot(y="expensive", data=df)

# %%
plt.figure(1 , figsize = (15 , 5))
sns.set(style="darkgrid")
ax = sns.countplot(y="healthy", data=df)

# %%
plt.figure(1 , figsize = (15 , 5))
sns.set(style="darkgrid")
ax = sns.countplot(y="disgusting", data=df)

# %%
plt.figure(1 , figsize = (15 , 5))
sns.set(style="darkgrid")
ax = sns.countplot(y="Gender", data=df)

# %%
plt.figure(1 , figsize = (15 , 5))
sns.set(style="darkgrid")
ax = sns.countplot(y="VisitFrequency", data=df)

# %%
age_18_25 = df.Age [(df.Age >= 18 ) & (df.Age <= 25 )]
age_26_35 = df.Age [(df.Age >= 26) & (df.Age <= 35 )]
age_36_45 = df.Age [(df.Age >= 36 ) & (df.Age <= 45 )]
age_46_55 = df.Age [(df.Age >= 46 ) & (df.Age <= 55 )]
age_55above = df.Age[df.Age >= 56]

agex = ["18-25" , "26-35 ","36-45", "46-55", "55+"]
agey = [len (age_18_25.values),len (age_26_35.values),len (age_36_45.values),len (age_46_55.values),len(age_55above.values)]

plt.figure(figsize=(15,6))
sns.barplot(x=agex, y=agey, palette = "mako")
plt.title("Number of Customer and Ages")
plt.xlabel("Age")
plt.ylabel("Number of Customer")
plt.show()

# %%
fig = px.scatter(df, x="Age", y="VisitFrequency", color="Gender", size='Age' )
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="890c720e-4e5c-43e9-93fe-a112374a1640" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("890c720e-4e5c-43e9-93fe-a112374a1640")) {
#                     Plotly.newPlot(
#                         '890c720e-4e5c-43e9-93fe-a112374a1640',
# ...

# %%
X1 = df.loc[:, ["Age", "VistFrequency"]].values
from sklearn.cluster import KMeans

WCSS = []

# Use k from 1 to 15
K = range(1,15)
for k in K:
    km = KMeans(n_clusters=k, init='random', n_init=10, max_iter=500,  tol=1e-04, random_state=0)
    km = km.fit(X)
    # Get sum of square distances by applying km.inertia_ 
    Sum_of_squared_distances.append(km.inertia_)

# Plot Results
plt.plot(K, Sum_of_squared_distances, marker='o')
plt.xlabel('k')
plt.ylabel('WCSS')
plt.title('Elbow Method For Optimal k')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-57-c561e6dd6112> in <module>()
# ----> 1 X1 = df.loc[:, ["Age", "VistFrequency"]].values
#       2 from sklearn.cluster import KMeans
#       3
#       4 WCSS = []
#       5
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#     871                     # AttributeError for IntervalTree get_value
#     872                     pass
# --> 873             return self._getitem_tuple(key)
#     874         else:
#     875             # we by definition only have the 0th axis
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    1053             return self._multi_take(tup)
#    1054
# -> 1055         return self._getitem_tuple_same_dim(tup)
#    1056
#    1057     def _get_label(self, label, axis: int):
#
# ...

# %%
kmeans = Kmeans (n_clusters = )

label = kmeans.fit_predict(X1)

print(label)

# %%
print(kmeans.cluster-centres_)

# %%
plt.scatter (X1[:,0], X1[:,1] , c=kmeans.labels_, cmap= 'rainbow')
plt.scatter(kmeans.cluster_centres_[:,0] , kmeans.cluster_centres_[:,1], color = 'black')
plt.title('Clusters of Customers ')
plt.xlabel('Age')
plt.ylabel('VisitFrequency')
plt.show()
